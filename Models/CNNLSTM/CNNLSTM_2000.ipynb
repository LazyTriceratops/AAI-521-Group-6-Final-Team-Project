# %% [markdown]
# <a href="https://colab.research.google.com/github/LazyTriceratops/AAI-521-Group-6-Final-Team-Project/blob/HernandezModelOne/CNNLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://Anitra-Hernandez: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@github.com/LazyTriceratops/AAI-521-Group-6-Final-Team-Project.git
# Out:
# Cloning into 'AAI-521-Group-6-Final-Team-Project'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 54 (delta 27), reused 37 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (54/54), 623.64 KiB | 10.39 MiB/s, done.
# Resolving deltas: 100% (27/27), done.

# %%
# %cd AAI-521-Group-6-Final-Team-Project
# Out:
# /content/AAI-521-Group-6-Final-Team-Project

# %%
# !git checkout HernandezModelOne
# Out:
# Branch 'HernandezModelOne' set up to track remote branch 'HernandezModelOne' from 'origin'.
# Switched to a new branch 'HernandezModelOne'

# %%
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import ParameterGrid

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/AAI-521/Final Project/Models/combined_dataset.pkl")

train_data = data[data['split'] == "train"]
val_data = data[data['split'] == 'val']
test_data = data[data['split'] == 'test']

# %%
# Extract padded_keypoints and label_index for each split
def extract_data(split_data):
    keypoints = np.stack(split_data['padded_keypoints'].values)  # Shape: [num_samples, 90, 33, 3]
    labels = split_data['label_index'].values                   # Shape: [num_samples]
    return keypoints, labels

train_keypoints, train_labels = extract_data(train_data)
val_keypoints, val_labels = extract_data(val_data)
test_keypoints, test_labels = extract_data(test_data)

# Convert to PyTorch tensors
train_keypoints = torch.tensor(train_keypoints, dtype=torch.float32)
train_labels = torch.tensor(train_labels, dtype=torch.long)

val_keypoints = torch.tensor(val_keypoints, dtype=torch.float32)
val_labels = torch.tensor(val_labels, dtype=torch.long)

test_keypoints = torch.tensor(test_keypoints, dtype=torch.float32)
test_labels = torch.tensor(test_labels, dtype=torch.long)

# Adjust labels to be zero-indexed
train_labels -= train_labels.min()
val_labels -= val_labels.min()
test_labels -= test_labels.min()

# Dynamically calculate number of classes
num_classes = max(train_labels.max().item(), val_labels.max().item(), test_labels.max().item()) + 1
print(f"Number of classes: {num_classes}")
print(f"Train labels range: {train_labels.min()} to {train_labels.max()}")
print(f"Validation labels range: {val_labels.min()} to {val_labels.max()}")
print(f"Test labels range: {test_labels.min()} to {test_labels.max()}")

print(f"Train data: {train_keypoints.shape}, {train_labels.shape}")
print(f"Val data: {val_keypoints.shape}, {val_labels.shape}")
print(f"Test data: {test_keypoints.shape}, {test_labels.shape}")
# Out:
# Number of classes: 2000
# Train labels range: 0 to 1999
# Validation labels range: 0 to 1996
# Test labels range: 0 to 1997
# Train data: torch.Size([8313, 90, 33, 3]), torch.Size([8313])
# Val data: torch.Size([2253, 90, 33, 3]), torch.Size([2253])
# Test data: torch.Size([1414, 90, 33, 3]), torch.Size([1414])

# %%
#Define custom dataset class
class PoseDataset(Dataset):
    def __init__(self, keypoints, labels):
        self.keypoints = keypoints  # Shape: [num_samples, 90, 33, 3]
        self.labels = labels        # Shape: [num_samples]

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        keypoint = self.keypoints[idx]  # Shape: [90, 33, 3]
        keypoint = keypoint.view(90, -1)  # Flatten to [90, 99]
        label = self.labels[idx]
        return keypoint, label

# %%
# Create DataLoaders
batch_size = 32
train_dataset = PoseDataset(train_keypoints, train_labels)
val_dataset = PoseDataset(val_keypoints, val_labels)
test_dataset = PoseDataset(test_keypoints, test_labels)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Inspect a batch of data
for inputs, labels in train_loader:
    print(f"Input shape: {inputs.shape}")
    print(f"Labels shape: {labels.shape}")
    break  # Just to check one batch
# Out:
# Input shape: torch.Size([32, 90, 99])
# Labels shape: torch.Size([32])

# %%
# Define EarlyStopping class
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = float('inf')
        self.counter = 0
        self.stop_training = False

    def __call__(self, val_loss):
        if self.best_loss - val_loss > self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.stop_training = True

# %%
# Define CNN + LSTM model
class CNNLSTM(nn.Module):
    def __init__(self, num_classes, input_dim=99, num_frames=90, cnn_hidden_dim=128, lstm_hidden_dim=256, lstm_layers=2):
        super(CNNLSTM, self).__init__()
        self.cnn = nn.Sequential(
            nn.Conv1d(in_channels=input_dim, out_channels=cnn_hidden_dim, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2),
            nn.Conv1d(in_channels=cnn_hidden_dim, out_channels=cnn_hidden_dim, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2)
        )
        self.lstm_input_size = cnn_hidden_dim
        self.lstm = nn.LSTM(
            input_size=self.lstm_input_size,
            hidden_size=lstm_hidden_dim,
            num_layers=lstm_layers,
            batch_first=True,
            bidirectional=True
        )
        self.fc = nn.Linear(lstm_hidden_dim * 2, num_classes)

    def forward(self, x, debug=False):  # Debug flag controls printing
        if debug:
            print(f"Input shape: {x.shape}")  # Debug input shape
        x = x.permute(0, 2, 1)
        x = self.cnn(x)
        if debug:
            print(f"After CNN shape: {x.shape}")  # Debug after CNN
        x = x.permute(0, 2, 1)
        lstm_out, _ = self.lstm(x)
        if debug:
            print(f"After LSTM shape: {lstm_out.shape}")  # Debug after LSTM
        lstm_out = lstm_out.mean(dim=1)
        out = self.fc(lstm_out)
        if debug:
            print(f"Output shape: {out.shape}, Expected: [batch_size, {num_classes}]")
        return out

# %%
# Training function
def train(model, train_loader, criterion, optimizer, device, debug_flag=False):
    model.train()
    running_loss = 0.0
    correct_preds = 0
    total_preds = 0

    for i, (inputs, labels) in enumerate(train_loader):
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        # Enable debug only for the first batch of training
        debug = debug_flag and (i == 0)
        outputs = model(inputs, debug=debug)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        correct_preds += (predicted == labels).sum().item()
        total_preds += labels.size(0)

    avg_loss = running_loss / len(train_loader)
    accuracy = correct_preds / total_preds * 100
    return avg_loss, accuracy

# Evaluation function
def evaluate(model, val_loader, criterion, device, debug_flag=False):
    model.eval()
    running_loss = 0.0
    correct_preds = 0
    total_preds = 0

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(val_loader):
            inputs, labels = inputs.to(device), labels.to(device)
            # Enable debug only for the first batch of evaluation
            debug = debug_flag and (i == 0)
            outputs = model(inputs, debug=debug)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            correct_preds += (predicted == labels).sum().item()
            total_preds += labels.size(0)

    avg_loss = running_loss / len(val_loader)
    accuracy = correct_preds / total_preds * 100
    return avg_loss, accuracy

# %%
# Define hyperparameter search space
param_grid = {
    'learning_rate': [1e-3, 5e-4, 1e-4],
    'cnn_hidden_dim': [64, 128, 256],
    'lstm_hidden_dim': [128, 256, 512],
    'lstm_layers': [1, 2],
    'weight_decay': [1e-5, 1e-4, 1e-3],
}

# Function to train and evaluate with hyperparameters
def train_and_evaluate_model(learning_rate, cnn_hidden_dim, lstm_hidden_dim, lstm_layers, weight_decay, num_classes, debug_flag=False):
    # Define the device
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Create model instance with current hyperparameters
    model = CNNLSTM(
        num_classes=num_classes,
        input_dim=99,
        num_frames=90,
        cnn_hidden_dim=cnn_hidden_dim,
        lstm_hidden_dim=lstm_hidden_dim,
        lstm_layers=lstm_layers
    )
    model = model.to(device)

    # Define optimizer and loss function
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    criterion = nn.CrossEntropyLoss()

    # Initialize Early Stopping and Scheduler
    early_stopping = EarlyStopping(patience=5, min_delta=0.01)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.1)

    # Training loop
    for epoch in range(50):  # Adjust max epochs as needed
        train_loss, train_acc = train(model, train_loader, criterion, optimizer, device, debug_flag=debug_flag and (epoch == 0))
        val_loss, val_acc = evaluate(model, val_loader, criterion, device, debug_flag=debug_flag and (epoch == 0))

        print(f"Epoch {epoch + 1}: Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%")

        # Update scheduler and check for early stopping
        scheduler.step(val_loss)
        early_stopping(val_loss)
        if early_stopping.stop_training:
            break

    return val_acc

# %%
# Perform hyperparameter search
best_val_acc = 0
best_hyperparams = {}

for params in ParameterGrid(param_grid):
    print(f"Training with parameters: {params}")
    # Enable debug only for the first set of hyperparameters
    debug_flag = (params == list(ParameterGrid(param_grid))[0])
    val_acc = train_and_evaluate_model(
        learning_rate=params['learning_rate'],
        cnn_hidden_dim=params['cnn_hidden_dim'],
        lstm_hidden_dim=params['lstm_hidden_dim'],
        lstm_layers=params['lstm_layers'],
        weight_decay=params['weight_decay'],
        num_classes=num_classes,
        debug_flag=debug_flag  # Pass debug flag
    )
    print(f"Validation Accuracy: {val_acc:.4f}")
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_hyperparams = params

print(f"Best Hyperparameters: {best_hyperparams}")
print(f"Best Validation Accuracy: {best_val_acc:.4f}")
# Out:
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.001, 'lstm_hidden_dim': 128, 'lstm_layers': 1, 'weight_decay': 1e-05}
# Input shape: torch.Size([32, 90, 99])
# After CNN shape: torch.Size([32, 64, 22])
# After LSTM shape: torch.Size([32, 22, 256])
# Output shape: torch.Size([32, 2000]), Expected: [batch_size, 2000]
# Input shape: torch.Size([32, 90, 99])
# After CNN shape: torch.Size([32, 64, 22])
# After LSTM shape: torch.Size([32, 22, 256])
# Output shape: torch.Size([32, 2000]), Expected: [batch_size, 2000]
# Epoch 1: Train Loss: 7.6077, Train Acc: 0.02%, Val Loss: 7.6097, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5945, Train Acc: 0.13%, Val Loss: 7.6053, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.5430, Train Acc: 0.17%, Val Loss: 7.4311, Val Acc: 0.13%
# Epoch 4: Train Loss: 7.2957, Train Acc: 0.17%, Val Loss: 7.3157, Val Acc: 0.13%
# Epoch 5: Train Loss: 7.1284, Train Acc: 0.17%, Val Loss: 7.3026, Val Acc: 0.18%
# Epoch 6: Train Loss: 7.0104, Train Acc: 0.18%, Val Loss: 7.3476, Val Acc: 0.04%
# Epoch 7: Train Loss: 6.8879, Train Acc: 0.24%, Val Loss: 7.3812, Val Acc: 0.36%
# Epoch 8: Train Loss: 6.7294, Train Acc: 0.41%, Val Loss: 7.4155, Val Acc: 0.36%
# Epoch 9: Train Loss: 6.5364, Train Acc: 0.64%, Val Loss: 7.4285, Val Acc: 0.49%
# Epoch 10: Train Loss: 6.1005, Train Acc: 2.36%, Val Loss: 7.5361, Val Acc: 0.36%
# Validation Accuracy: 0.3551
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.001, 'lstm_hidden_dim': 128, 'lstm_layers': 1, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6088, Train Acc: 0.07%, Val Loss: 7.6063, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5952, Train Acc: 0.10%, Val Loss: 7.6124, Val Acc: 0.00%
# Epoch 3: Train Loss: 7.5857, Train Acc: 0.14%, Val Loss: 7.6040, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.4948, Train Acc: 0.08%, Val Loss: 7.4019, Val Acc: 0.22%
# Epoch 5: Train Loss: 7.2407, Train Acc: 0.13%, Val Loss: 7.3134, Val Acc: 0.27%
# Epoch 6: Train Loss: 7.0802, Train Acc: 0.29%, Val Loss: 7.3046, Val Acc: 0.18%
# Epoch 7: Train Loss: 6.9612, Train Acc: 0.24%, Val Loss: 7.3306, Val Acc: 0.09%
# Epoch 8: Train Loss: 6.8288, Train Acc: 0.32%, Val Loss: 7.3462, Val Acc: 0.31%
# Epoch 9: Train Loss: 6.6552, Train Acc: 0.49%, Val Loss: 7.3989, Val Acc: 0.53%
# Epoch 10: Train Loss: 6.4823, Train Acc: 0.76%, Val Loss: 7.4331, Val Acc: 0.27%
# Validation Accuracy: 0.2663
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.001, 'lstm_hidden_dim': 128, 'lstm_layers': 1, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6089, Train Acc: 0.05%, Val Loss: 7.6018, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5958, Train Acc: 0.10%, Val Loss: 7.6042, Val Acc: 0.00%
# Epoch 3: Train Loss: 7.5937, Train Acc: 0.10%, Val Loss: 7.6006, Val Acc: 0.18%
# Epoch 4: Train Loss: 7.5906, Train Acc: 0.07%, Val Loss: 7.6008, Val Acc: 0.13%
# Epoch 5: Train Loss: 7.5881, Train Acc: 0.10%, Val Loss: 7.6008, Val Acc: 0.13%
# Epoch 6: Train Loss: 7.5860, Train Acc: 0.10%, Val Loss: 7.6008, Val Acc: 0.13%
# Validation Accuracy: 0.1332
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.001, 'lstm_hidden_dim': 128, 'lstm_layers': 2, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6069, Train Acc: 0.05%, Val Loss: 7.6031, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5882, Train Acc: 0.02%, Val Loss: 7.5277, Val Acc: 0.13%
# Epoch 3: Train Loss: 7.3827, Train Acc: 0.10%, Val Loss: 7.3014, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.2230, Train Acc: 0.07%, Val Loss: 7.2852, Val Acc: 0.09%
# Epoch 5: Train Loss: 7.1339, Train Acc: 0.08%, Val Loss: 7.2715, Val Acc: 0.18%
# Epoch 6: Train Loss: 7.0583, Train Acc: 0.22%, Val Loss: 7.2684, Val Acc: 0.27%
# Epoch 7: Train Loss: 6.9835, Train Acc: 0.26%, Val Loss: 7.3166, Val Acc: 0.09%
# Epoch 8: Train Loss: 6.8783, Train Acc: 0.37%, Val Loss: 7.3211, Val Acc: 0.09%
# Epoch 9: Train Loss: 6.7670, Train Acc: 0.30%, Val Loss: 7.3814, Val Acc: 0.18%
# Epoch 10: Train Loss: 6.6330, Train Acc: 0.54%, Val Loss: 7.5076, Val Acc: 0.13%
# Validation Accuracy: 0.1332
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.001, 'lstm_hidden_dim': 128, 'lstm_layers': 2, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6087, Train Acc: 0.02%, Val Loss: 7.6166, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5967, Train Acc: 0.04%, Val Loss: 7.6019, Val Acc: 0.00%
# Epoch 3: Train Loss: 7.5884, Train Acc: 0.14%, Val Loss: 7.6021, Val Acc: 0.00%
# Epoch 4: Train Loss: 7.5801, Train Acc: 0.04%, Val Loss: 7.6011, Val Acc: 0.13%
# Epoch 5: Train Loss: 7.5710, Train Acc: 0.08%, Val Loss: 7.6039, Val Acc: 0.04%
# Epoch 6: Train Loss: 7.5268, Train Acc: 0.13%, Val Loss: 7.5388, Val Acc: 0.04%
# Epoch 7: Train Loss: 7.3461, Train Acc: 0.06%, Val Loss: 7.3677, Val Acc: 0.22%
# Epoch 8: Train Loss: 7.1769, Train Acc: 0.14%, Val Loss: 7.3288, Val Acc: 0.18%
# Epoch 9: Train Loss: 7.0800, Train Acc: 0.26%, Val Loss: 7.3091, Val Acc: 0.22%
# Epoch 10: Train Loss: 6.9663, Train Acc: 0.28%, Val Loss: 7.3491, Val Acc: 0.22%
# Epoch 11: Train Loss: 6.8406, Train Acc: 0.34%, Val Loss: 7.3432, Val Acc: 0.36%
# Epoch 12: Train Loss: 6.6800, Train Acc: 0.66%, Val Loss: 7.3379, Val Acc: 0.49%
# Epoch 13: Train Loss: 6.5012, Train Acc: 0.75%, Val Loss: 7.4476, Val Acc: 0.40%
# Epoch 14: Train Loss: 6.0292, Train Acc: 2.60%, Val Loss: 7.4840, Val Acc: 0.62%
# Validation Accuracy: 0.6214
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.001, 'lstm_hidden_dim': 128, 'lstm_layers': 2, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6086, Train Acc: 0.10%, Val Loss: 7.6014, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5964, Train Acc: 0.12%, Val Loss: 7.6011, Val Acc: 0.09%
# Epoch 3: Train Loss: 7.5931, Train Acc: 0.10%, Val Loss: 7.6009, Val Acc: 0.09%
# Epoch 4: Train Loss: 7.5904, Train Acc: 0.12%, Val Loss: 7.6008, Val Acc: 0.09%
# Epoch 5: Train Loss: 7.5880, Train Acc: 0.11%, Val Loss: 7.6007, Val Acc: 0.13%
# Epoch 6: Train Loss: 7.5836, Train Acc: 0.13%, Val Loss: 7.6007, Val Acc: 0.13%
# Validation Accuracy: 0.1332
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.001, 'lstm_hidden_dim': 256, 'lstm_layers': 1, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6071, Train Acc: 0.04%, Val Loss: 7.6027, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5937, Train Acc: 0.05%, Val Loss: 7.5941, Val Acc: 0.13%
# Epoch 3: Train Loss: 7.4518, Train Acc: 0.12%, Val Loss: 7.3450, Val Acc: 0.18%
# Epoch 4: Train Loss: 7.1955, Train Acc: 0.14%, Val Loss: 7.2984, Val Acc: 0.22%
# Epoch 5: Train Loss: 7.0159, Train Acc: 0.23%, Val Loss: 7.3302, Val Acc: 0.31%
# Epoch 6: Train Loss: 6.8469, Train Acc: 0.43%, Val Loss: 7.3170, Val Acc: 0.27%
# Epoch 7: Train Loss: 6.6275, Train Acc: 0.59%, Val Loss: 7.3725, Val Acc: 0.27%
# Epoch 8: Train Loss: 6.3600, Train Acc: 0.93%, Val Loss: 7.4515, Val Acc: 0.31%
# Epoch 9: Train Loss: 5.7218, Train Acc: 4.32%, Val Loss: 7.5932, Val Acc: 0.49%
# Validation Accuracy: 0.4882
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.001, 'lstm_hidden_dim': 256, 'lstm_layers': 1, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6070, Train Acc: 0.04%, Val Loss: 7.6085, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5948, Train Acc: 0.17%, Val Loss: 7.6009, Val Acc: 0.09%
# Epoch 3: Train Loss: 7.5473, Train Acc: 0.08%, Val Loss: 7.4201, Val Acc: 0.18%
# Epoch 4: Train Loss: 7.3123, Train Acc: 0.10%, Val Loss: 7.2974, Val Acc: 0.22%
# Epoch 5: Train Loss: 7.1345, Train Acc: 0.13%, Val Loss: 7.2767, Val Acc: 0.40%
# Epoch 6: Train Loss: 7.0092, Train Acc: 0.19%, Val Loss: 7.2745, Val Acc: 0.27%
# Epoch 7: Train Loss: 6.8723, Train Acc: 0.31%, Val Loss: 7.2764, Val Acc: 0.31%
# Epoch 8: Train Loss: 6.7063, Train Acc: 0.49%, Val Loss: 7.3023, Val Acc: 0.27%
# Epoch 9: Train Loss: 6.4996, Train Acc: 0.52%, Val Loss: 7.3736, Val Acc: 0.36%
# Epoch 10: Train Loss: 6.2592, Train Acc: 1.19%, Val Loss: 7.4683, Val Acc: 0.36%
# Validation Accuracy: 0.3551
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.001, 'lstm_hidden_dim': 256, 'lstm_layers': 1, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6083, Train Acc: 0.05%, Val Loss: 7.6004, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5954, Train Acc: 0.11%, Val Loss: 7.6004, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.5926, Train Acc: 0.14%, Val Loss: 7.6002, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.5900, Train Acc: 0.08%, Val Loss: 7.6002, Val Acc: 0.04%
# Epoch 5: Train Loss: 7.5876, Train Acc: 0.08%, Val Loss: 7.6007, Val Acc: 0.04%
# Epoch 6: Train Loss: 7.5832, Train Acc: 0.14%, Val Loss: 7.6007, Val Acc: 0.04%
# Validation Accuracy: 0.0444
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.001, 'lstm_hidden_dim': 256, 'lstm_layers': 2, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6066, Train Acc: 0.02%, Val Loss: 7.6013, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5953, Train Acc: 0.08%, Val Loss: 7.6035, Val Acc: 0.09%
# Epoch 3: Train Loss: 7.5871, Train Acc: 0.07%, Val Loss: 7.5764, Val Acc: 0.18%
# Epoch 4: Train Loss: 7.4777, Train Acc: 0.10%, Val Loss: 7.3675, Val Acc: 0.13%
# Epoch 5: Train Loss: 7.2576, Train Acc: 0.14%, Val Loss: 7.2816, Val Acc: 0.13%
# Epoch 6: Train Loss: 7.1284, Train Acc: 0.17%, Val Loss: 7.2434, Val Acc: 0.27%
# Epoch 7: Train Loss: 7.0226, Train Acc: 0.26%, Val Loss: 7.2575, Val Acc: 0.36%
# Epoch 8: Train Loss: 7.0209, Train Acc: 0.24%, Val Loss: 7.3117, Val Acc: 0.09%
# Epoch 9: Train Loss: 6.8768, Train Acc: 0.31%, Val Loss: 7.3179, Val Acc: 0.22%
# Epoch 10: Train Loss: 6.7161, Train Acc: 0.57%, Val Loss: 7.3359, Val Acc: 0.22%
# Epoch 11: Train Loss: 6.3318, Train Acc: 1.30%, Val Loss: 7.4692, Val Acc: 0.36%
# Validation Accuracy: 0.3551
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.001, 'lstm_hidden_dim': 256, 'lstm_layers': 2, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6074, Train Acc: 0.07%, Val Loss: 7.6022, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5956, Train Acc: 0.05%, Val Loss: 7.6017, Val Acc: 0.09%
# Epoch 3: Train Loss: 7.5895, Train Acc: 0.05%, Val Loss: 7.6044, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.5850, Train Acc: 0.07%, Val Loss: 7.6026, Val Acc: 0.13%
# Epoch 5: Train Loss: 7.5767, Train Acc: 0.05%, Val Loss: 7.6023, Val Acc: 0.13%
# Epoch 6: Train Loss: 7.5323, Train Acc: 0.16%, Val Loss: 7.6493, Val Acc: 0.09%
# Validation Accuracy: 0.0888
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.001, 'lstm_hidden_dim': 256, 'lstm_layers': 2, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6084, Train Acc: 0.05%, Val Loss: 7.6003, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5960, Train Acc: 0.06%, Val Loss: 7.6001, Val Acc: 0.09%
# Epoch 3: Train Loss: 7.5928, Train Acc: 0.05%, Val Loss: 7.6000, Val Acc: 0.09%
# Epoch 4: Train Loss: 7.5901, Train Acc: 0.11%, Val Loss: 7.6000, Val Acc: 0.09%
# Epoch 5: Train Loss: 7.5878, Train Acc: 0.06%, Val Loss: 7.6001, Val Acc: 0.09%
# Epoch 6: Train Loss: 7.5834, Train Acc: 0.12%, Val Loss: 7.6001, Val Acc: 0.09%
# Validation Accuracy: 0.0888
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.001, 'lstm_hidden_dim': 512, 'lstm_layers': 1, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6067, Train Acc: 0.02%, Val Loss: 7.6097, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5953, Train Acc: 0.11%, Val Loss: 7.6040, Val Acc: 0.00%
# Epoch 3: Train Loss: 7.5714, Train Acc: 0.08%, Val Loss: 7.5226, Val Acc: 0.00%
# Epoch 4: Train Loss: 7.3776, Train Acc: 0.11%, Val Loss: 7.3319, Val Acc: 0.09%
# Epoch 5: Train Loss: 7.1940, Train Acc: 0.17%, Val Loss: 7.3060, Val Acc: 0.09%
# Epoch 6: Train Loss: 7.0804, Train Acc: 0.20%, Val Loss: 7.3158, Val Acc: 0.31%
# Epoch 7: Train Loss: 6.9279, Train Acc: 0.29%, Val Loss: 7.3517, Val Acc: 0.18%
# Epoch 8: Train Loss: 6.7394, Train Acc: 0.45%, Val Loss: 7.4247, Val Acc: 0.09%
# Epoch 9: Train Loss: 6.5284, Train Acc: 0.59%, Val Loss: 7.4658, Val Acc: 0.44%
# Epoch 10: Train Loss: 5.9601, Train Acc: 2.86%, Val Loss: 7.6663, Val Acc: 0.53%
# Validation Accuracy: 0.5326
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.001, 'lstm_hidden_dim': 512, 'lstm_layers': 1, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6083, Train Acc: 0.05%, Val Loss: 7.6143, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5710, Train Acc: 0.12%, Val Loss: 7.4303, Val Acc: 0.09%
# Epoch 3: Train Loss: 7.3666, Train Acc: 0.14%, Val Loss: 7.3044, Val Acc: 0.18%
# Epoch 4: Train Loss: 7.2159, Train Acc: 0.22%, Val Loss: 7.2708, Val Acc: 0.09%
# Epoch 5: Train Loss: 7.1364, Train Acc: 0.22%, Val Loss: 7.2497, Val Acc: 0.22%
# Epoch 6: Train Loss: 7.0485, Train Acc: 0.24%, Val Loss: 7.2195, Val Acc: 0.18%
# Epoch 7: Train Loss: 6.9538, Train Acc: 0.31%, Val Loss: 7.2178, Val Acc: 0.36%
# Epoch 8: Train Loss: 6.8284, Train Acc: 0.31%, Val Loss: 7.2630, Val Acc: 0.31%
# Epoch 9: Train Loss: 6.6950, Train Acc: 0.49%, Val Loss: 7.2827, Val Acc: 0.36%
# Epoch 10: Train Loss: 6.5369, Train Acc: 0.83%, Val Loss: 7.3268, Val Acc: 0.22%
# Epoch 11: Train Loss: 6.3483, Train Acc: 1.19%, Val Loss: 7.4217, Val Acc: 0.44%
# Validation Accuracy: 0.4439
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.001, 'lstm_hidden_dim': 512, 'lstm_layers': 1, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6083, Train Acc: 0.05%, Val Loss: 7.6006, Val Acc: 0.00%
# Epoch 2: Train Loss: 7.5957, Train Acc: 0.08%, Val Loss: 7.6026, Val Acc: 0.09%
# Epoch 3: Train Loss: 7.5929, Train Acc: 0.07%, Val Loss: 7.6006, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.5900, Train Acc: 0.14%, Val Loss: 7.6006, Val Acc: 0.04%
# Epoch 5: Train Loss: 7.5877, Train Acc: 0.06%, Val Loss: 7.6009, Val Acc: 0.09%
# Epoch 6: Train Loss: 7.5837, Train Acc: 0.16%, Val Loss: 7.6006, Val Acc: 0.04%
# Validation Accuracy: 0.0444
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.001, 'lstm_hidden_dim': 512, 'lstm_layers': 2, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6049, Train Acc: 0.04%, Val Loss: 7.6052, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5954, Train Acc: 0.06%, Val Loss: 7.6008, Val Acc: 0.13%
# Epoch 3: Train Loss: 7.5265, Train Acc: 0.10%, Val Loss: 7.4273, Val Acc: 0.09%
# Epoch 4: Train Loss: 7.3040, Train Acc: 0.10%, Val Loss: 7.3155, Val Acc: 0.00%
# Epoch 5: Train Loss: 7.1630, Train Acc: 0.13%, Val Loss: 7.3408, Val Acc: 0.13%
# Epoch 6: Train Loss: 7.0716, Train Acc: 0.25%, Val Loss: 7.3426, Val Acc: 0.13%
# Epoch 7: Train Loss: 6.9211, Train Acc: 0.26%, Val Loss: 7.3289, Val Acc: 0.09%
# Epoch 8: Train Loss: 6.7519, Train Acc: 0.38%, Val Loss: 7.4327, Val Acc: 0.13%
# Epoch 9: Train Loss: 6.2250, Train Acc: 1.86%, Val Loss: 7.5763, Val Acc: 0.31%
# Validation Accuracy: 0.3107
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.001, 'lstm_hidden_dim': 512, 'lstm_layers': 2, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6074, Train Acc: 0.01%, Val Loss: 7.6024, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5954, Train Acc: 0.10%, Val Loss: 7.6031, Val Acc: 0.09%
# Epoch 3: Train Loss: 7.5906, Train Acc: 0.10%, Val Loss: 7.6039, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.5858, Train Acc: 0.12%, Val Loss: 7.6018, Val Acc: 0.13%
# Epoch 5: Train Loss: 7.5803, Train Acc: 0.18%, Val Loss: 7.6031, Val Acc: 0.13%
# Epoch 6: Train Loss: 7.5627, Train Acc: 0.10%, Val Loss: 7.6257, Val Acc: 0.09%
# Validation Accuracy: 0.0888
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.001, 'lstm_hidden_dim': 512, 'lstm_layers': 2, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6082, Train Acc: 0.07%, Val Loss: 7.6006, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5964, Train Acc: 0.06%, Val Loss: 7.6003, Val Acc: 0.13%
# Epoch 3: Train Loss: 7.5932, Train Acc: 0.12%, Val Loss: 7.6002, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.5903, Train Acc: 0.08%, Val Loss: 7.6003, Val Acc: 0.04%
# Epoch 5: Train Loss: 7.5882, Train Acc: 0.12%, Val Loss: 7.6004, Val Acc: 0.04%
# Epoch 6: Train Loss: 7.5840, Train Acc: 0.14%, Val Loss: 7.6003, Val Acc: 0.04%
# Validation Accuracy: 0.0444
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0005, 'lstm_hidden_dim': 128, 'lstm_layers': 1, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6058, Train Acc: 0.02%, Val Loss: 7.6050, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5924, Train Acc: 0.08%, Val Loss: 7.5873, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.4104, Train Acc: 0.07%, Val Loss: 7.3194, Val Acc: 0.18%
# Epoch 4: Train Loss: 7.1645, Train Acc: 0.17%, Val Loss: 7.2988, Val Acc: 0.18%
# Epoch 5: Train Loss: 7.0205, Train Acc: 0.24%, Val Loss: 7.3202, Val Acc: 0.31%
# Epoch 6: Train Loss: 6.8871, Train Acc: 0.37%, Val Loss: 7.3210, Val Acc: 0.27%
# Epoch 7: Train Loss: 6.7479, Train Acc: 0.47%, Val Loss: 7.3604, Val Acc: 0.49%
# Epoch 8: Train Loss: 6.5987, Train Acc: 0.75%, Val Loss: 7.3921, Val Acc: 0.58%
# Epoch 9: Train Loss: 6.2656, Train Acc: 2.06%, Val Loss: 7.4475, Val Acc: 0.40%
# Validation Accuracy: 0.3995
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0005, 'lstm_hidden_dim': 128, 'lstm_layers': 1, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6063, Train Acc: 0.06%, Val Loss: 7.6048, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5858, Train Acc: 0.05%, Val Loss: 7.4992, Val Acc: 0.13%
# Epoch 3: Train Loss: 7.3761, Train Acc: 0.05%, Val Loss: 7.3000, Val Acc: 0.09%
# Epoch 4: Train Loss: 7.1869, Train Acc: 0.11%, Val Loss: 7.2640, Val Acc: 0.27%
# Epoch 5: Train Loss: 7.0820, Train Acc: 0.20%, Val Loss: 7.2897, Val Acc: 0.04%
# Epoch 6: Train Loss: 6.9906, Train Acc: 0.31%, Val Loss: 7.2982, Val Acc: 0.09%
# Epoch 7: Train Loss: 6.8962, Train Acc: 0.35%, Val Loss: 7.3030, Val Acc: 0.27%
# Epoch 8: Train Loss: 6.7836, Train Acc: 0.53%, Val Loss: 7.3094, Val Acc: 0.22%
# Epoch 9: Train Loss: 6.5151, Train Acc: 1.17%, Val Loss: 7.3541, Val Acc: 0.27%
# Validation Accuracy: 0.2663
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0005, 'lstm_hidden_dim': 128, 'lstm_layers': 1, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6063, Train Acc: 0.07%, Val Loss: 7.6007, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5983, Train Acc: 0.06%, Val Loss: 7.6007, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.5952, Train Acc: 0.07%, Val Loss: 7.5996, Val Acc: 0.09%
# Epoch 4: Train Loss: 7.5786, Train Acc: 0.11%, Val Loss: 7.5045, Val Acc: 0.09%
# Epoch 5: Train Loss: 7.3749, Train Acc: 0.13%, Val Loss: 7.3186, Val Acc: 0.09%
# Epoch 6: Train Loss: 7.2285, Train Acc: 0.13%, Val Loss: 7.2830, Val Acc: 0.22%
# Epoch 7: Train Loss: 7.1699, Train Acc: 0.10%, Val Loss: 7.2714, Val Acc: 0.27%
# Epoch 8: Train Loss: 7.1330, Train Acc: 0.18%, Val Loss: 7.2676, Val Acc: 0.18%
# Epoch 9: Train Loss: 7.0980, Train Acc: 0.14%, Val Loss: 7.2618, Val Acc: 0.13%
# Epoch 10: Train Loss: 7.0578, Train Acc: 0.23%, Val Loss: 7.2512, Val Acc: 0.22%
# Epoch 11: Train Loss: 7.0187, Train Acc: 0.17%, Val Loss: 7.2374, Val Acc: 0.27%
# Epoch 12: Train Loss: 6.9740, Train Acc: 0.22%, Val Loss: 7.2627, Val Acc: 0.27%
# Epoch 13: Train Loss: 6.9192, Train Acc: 0.25%, Val Loss: 7.2657, Val Acc: 0.36%
# Epoch 14: Train Loss: 6.8614, Train Acc: 0.38%, Val Loss: 7.2685, Val Acc: 0.27%
# Epoch 15: Train Loss: 6.8046, Train Acc: 0.47%, Val Loss: 7.2917, Val Acc: 0.27%
# Epoch 16: Train Loss: 6.5921, Train Acc: 1.12%, Val Loss: 7.3088, Val Acc: 0.22%
# Validation Accuracy: 0.2219
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0005, 'lstm_hidden_dim': 128, 'lstm_layers': 2, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6054, Train Acc: 0.10%, Val Loss: 7.6083, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5966, Train Acc: 0.07%, Val Loss: 7.6037, Val Acc: 0.00%
# Epoch 3: Train Loss: 7.5836, Train Acc: 0.08%, Val Loss: 7.6037, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.5198, Train Acc: 0.11%, Val Loss: 7.4408, Val Acc: 0.00%
# Epoch 5: Train Loss: 7.2687, Train Acc: 0.18%, Val Loss: 7.3390, Val Acc: 0.04%
# Epoch 6: Train Loss: 7.0782, Train Acc: 0.18%, Val Loss: 7.3341, Val Acc: 0.22%
# Epoch 7: Train Loss: 6.9615, Train Acc: 0.26%, Val Loss: 7.3367, Val Acc: 0.22%
# Epoch 8: Train Loss: 6.8432, Train Acc: 0.30%, Val Loss: 7.3743, Val Acc: 0.36%
# Epoch 9: Train Loss: 6.7115, Train Acc: 0.57%, Val Loss: 7.4180, Val Acc: 0.18%
# Epoch 10: Train Loss: 6.5636, Train Acc: 0.60%, Val Loss: 7.5095, Val Acc: 0.31%
# Validation Accuracy: 0.3107
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0005, 'lstm_hidden_dim': 128, 'lstm_layers': 2, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6073, Train Acc: 0.04%, Val Loss: 7.6035, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5918, Train Acc: 0.10%, Val Loss: 7.5296, Val Acc: 0.00%
# Epoch 3: Train Loss: 7.3925, Train Acc: 0.10%, Val Loss: 7.3191, Val Acc: 0.09%
# Epoch 4: Train Loss: 7.2276, Train Acc: 0.13%, Val Loss: 7.2868, Val Acc: 0.13%
# Epoch 5: Train Loss: 7.1486, Train Acc: 0.16%, Val Loss: 7.2645, Val Acc: 0.18%
# Epoch 6: Train Loss: 7.0873, Train Acc: 0.18%, Val Loss: 7.2797, Val Acc: 0.22%
# Epoch 7: Train Loss: 7.0017, Train Acc: 0.22%, Val Loss: 7.2871, Val Acc: 0.40%
# Epoch 8: Train Loss: 6.9105, Train Acc: 0.43%, Val Loss: 7.3369, Val Acc: 0.31%
# Epoch 9: Train Loss: 6.8271, Train Acc: 0.40%, Val Loss: 7.3587, Val Acc: 0.27%
# Epoch 10: Train Loss: 6.5733, Train Acc: 0.72%, Val Loss: 7.4028, Val Acc: 0.22%
# Validation Accuracy: 0.2219
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0005, 'lstm_hidden_dim': 128, 'lstm_layers': 2, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6057, Train Acc: 0.02%, Val Loss: 7.6008, Val Acc: 0.13%
# Epoch 2: Train Loss: 7.5983, Train Acc: 0.07%, Val Loss: 7.6006, Val Acc: 0.09%
# Epoch 3: Train Loss: 7.5959, Train Acc: 0.06%, Val Loss: 7.6004, Val Acc: 0.13%
# Epoch 4: Train Loss: 7.5937, Train Acc: 0.12%, Val Loss: 7.6003, Val Acc: 0.04%
# Epoch 5: Train Loss: 7.5909, Train Acc: 0.14%, Val Loss: 7.6004, Val Acc: 0.04%
# Epoch 6: Train Loss: 7.5817, Train Acc: 0.14%, Val Loss: 7.6008, Val Acc: 0.04%
# Validation Accuracy: 0.0444
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0005, 'lstm_hidden_dim': 256, 'lstm_layers': 1, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6051, Train Acc: 0.04%, Val Loss: 7.6053, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5932, Train Acc: 0.06%, Val Loss: 7.5837, Val Acc: 0.13%
# Epoch 3: Train Loss: 7.4326, Train Acc: 0.06%, Val Loss: 7.3538, Val Acc: 0.18%
# Epoch 4: Train Loss: 7.2114, Train Acc: 0.17%, Val Loss: 7.3052, Val Acc: 0.22%
# Epoch 5: Train Loss: 7.1135, Train Acc: 0.12%, Val Loss: 7.2907, Val Acc: 0.09%
# Epoch 6: Train Loss: 7.0134, Train Acc: 0.20%, Val Loss: 7.2710, Val Acc: 0.36%
# Epoch 7: Train Loss: 6.8953, Train Acc: 0.34%, Val Loss: 7.3358, Val Acc: 0.18%
# Epoch 8: Train Loss: 6.7496, Train Acc: 0.45%, Val Loss: 7.3322, Val Acc: 0.13%
# Epoch 9: Train Loss: 6.5883, Train Acc: 0.59%, Val Loss: 7.3757, Val Acc: 0.22%
# Epoch 10: Train Loss: 6.3909, Train Acc: 0.91%, Val Loss: 7.4744, Val Acc: 0.40%
# Epoch 11: Train Loss: 5.9385, Train Acc: 2.96%, Val Loss: 7.5319, Val Acc: 0.27%
# Validation Accuracy: 0.2663
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0005, 'lstm_hidden_dim': 256, 'lstm_layers': 1, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6061, Train Acc: 0.01%, Val Loss: 7.6027, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5947, Train Acc: 0.08%, Val Loss: 7.5899, Val Acc: 0.13%
# Epoch 3: Train Loss: 7.4552, Train Acc: 0.12%, Val Loss: 7.3419, Val Acc: 0.13%
# Epoch 4: Train Loss: 7.2235, Train Acc: 0.12%, Val Loss: 7.2896, Val Acc: 0.22%
# Epoch 5: Train Loss: 7.1004, Train Acc: 0.23%, Val Loss: 7.2906, Val Acc: 0.27%
# Epoch 6: Train Loss: 6.9916, Train Acc: 0.18%, Val Loss: 7.2879, Val Acc: 0.22%
# Epoch 7: Train Loss: 6.8632, Train Acc: 0.34%, Val Loss: 7.2930, Val Acc: 0.22%
# Epoch 8: Train Loss: 6.7001, Train Acc: 0.48%, Val Loss: 7.3298, Val Acc: 0.27%
# Epoch 9: Train Loss: 6.5203, Train Acc: 0.73%, Val Loss: 7.3699, Val Acc: 0.18%
# Validation Accuracy: 0.1775
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0005, 'lstm_hidden_dim': 256, 'lstm_layers': 1, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6064, Train Acc: 0.05%, Val Loss: 7.5999, Val Acc: 0.00%
# Epoch 2: Train Loss: 7.5985, Train Acc: 0.02%, Val Loss: 7.6003, Val Acc: 0.00%
# Epoch 3: Train Loss: 7.5936, Train Acc: 0.10%, Val Loss: 7.5796, Val Acc: 0.09%
# Epoch 4: Train Loss: 7.4263, Train Acc: 0.06%, Val Loss: 7.3209, Val Acc: 0.18%
# Epoch 5: Train Loss: 7.2564, Train Acc: 0.11%, Val Loss: 7.2923, Val Acc: 0.09%
# Epoch 6: Train Loss: 7.1989, Train Acc: 0.14%, Val Loss: 7.2769, Val Acc: 0.18%
# Epoch 7: Train Loss: 7.1566, Train Acc: 0.18%, Val Loss: 7.2789, Val Acc: 0.09%
# Epoch 8: Train Loss: 7.1289, Train Acc: 0.25%, Val Loss: 7.2560, Val Acc: 0.09%
# Epoch 9: Train Loss: 7.1019, Train Acc: 0.17%, Val Loss: 7.2569, Val Acc: 0.27%
# Epoch 10: Train Loss: 7.0717, Train Acc: 0.25%, Val Loss: 7.2467, Val Acc: 0.27%
# Epoch 11: Train Loss: 7.0354, Train Acc: 0.24%, Val Loss: 7.2448, Val Acc: 0.22%
# Epoch 12: Train Loss: 6.9841, Train Acc: 0.29%, Val Loss: 7.2506, Val Acc: 0.18%
# Epoch 13: Train Loss: 6.9391, Train Acc: 0.35%, Val Loss: 7.2021, Val Acc: 0.13%
# Epoch 14: Train Loss: 6.8909, Train Acc: 0.36%, Val Loss: 7.2141, Val Acc: 0.22%
# Epoch 15: Train Loss: 6.8420, Train Acc: 0.45%, Val Loss: 7.2253, Val Acc: 0.36%
# Epoch 16: Train Loss: 6.7883, Train Acc: 0.38%, Val Loss: 7.2543, Val Acc: 0.40%
# Epoch 17: Train Loss: 6.7341, Train Acc: 0.60%, Val Loss: 7.2608, Val Acc: 0.36%
# Epoch 18: Train Loss: 6.4880, Train Acc: 1.21%, Val Loss: 7.2939, Val Acc: 0.36%
# Validation Accuracy: 0.3551
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0005, 'lstm_hidden_dim': 256, 'lstm_layers': 2, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6039, Train Acc: 0.04%, Val Loss: 7.6097, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5935, Train Acc: 0.05%, Val Loss: 7.6029, Val Acc: 0.09%
# Epoch 3: Train Loss: 7.5007, Train Acc: 0.08%, Val Loss: 7.3956, Val Acc: 0.09%
# Epoch 4: Train Loss: 7.2611, Train Acc: 0.11%, Val Loss: 7.3209, Val Acc: 0.22%
# Epoch 5: Train Loss: 7.1329, Train Acc: 0.17%, Val Loss: 7.3125, Val Acc: 0.22%
# Epoch 6: Train Loss: 7.0350, Train Acc: 0.24%, Val Loss: 7.3056, Val Acc: 0.09%
# Epoch 7: Train Loss: 6.9202, Train Acc: 0.41%, Val Loss: 7.3198, Val Acc: 0.22%
# Epoch 8: Train Loss: 6.7863, Train Acc: 0.38%, Val Loss: 7.3624, Val Acc: 0.27%
# Epoch 9: Train Loss: 6.6205, Train Acc: 0.53%, Val Loss: 7.4155, Val Acc: 0.22%
# Epoch 10: Train Loss: 6.4291, Train Acc: 0.78%, Val Loss: 7.4999, Val Acc: 0.27%
# Epoch 11: Train Loss: 5.9687, Train Acc: 2.73%, Val Loss: 7.5646, Val Acc: 0.36%
# Validation Accuracy: 0.3551
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0005, 'lstm_hidden_dim': 256, 'lstm_layers': 2, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6046, Train Acc: 0.05%, Val Loss: 7.6040, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5977, Train Acc: 0.06%, Val Loss: 7.5997, Val Acc: 0.13%
# Epoch 3: Train Loss: 7.5872, Train Acc: 0.08%, Val Loss: 7.6025, Val Acc: 0.22%
# Epoch 4: Train Loss: 7.5658, Train Acc: 0.10%, Val Loss: 7.6088, Val Acc: 0.09%
# Epoch 5: Train Loss: 7.4651, Train Acc: 0.07%, Val Loss: 7.4120, Val Acc: 0.13%
# Epoch 6: Train Loss: 7.2364, Train Acc: 0.07%, Val Loss: 7.3414, Val Acc: 0.13%
# Epoch 7: Train Loss: 7.1050, Train Acc: 0.22%, Val Loss: 7.3323, Val Acc: 0.18%
# Epoch 8: Train Loss: 6.9849, Train Acc: 0.22%, Val Loss: 7.3345, Val Acc: 0.22%
# Epoch 9: Train Loss: 6.8740, Train Acc: 0.38%, Val Loss: 7.3790, Val Acc: 0.13%
# Epoch 10: Train Loss: 6.7714, Train Acc: 0.43%, Val Loss: 7.4231, Val Acc: 0.40%
# Epoch 11: Train Loss: 6.6193, Train Acc: 0.57%, Val Loss: 7.4567, Val Acc: 0.27%
# Validation Accuracy: 0.2663
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0005, 'lstm_hidden_dim': 256, 'lstm_layers': 2, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6056, Train Acc: 0.07%, Val Loss: 7.6006, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5977, Train Acc: 0.02%, Val Loss: 7.6010, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.5957, Train Acc: 0.11%, Val Loss: 7.6009, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.5939, Train Acc: 0.08%, Val Loss: 7.6008, Val Acc: 0.04%
# Epoch 5: Train Loss: 7.5920, Train Acc: 0.14%, Val Loss: 7.6007, Val Acc: 0.04%
# Epoch 6: Train Loss: 7.5879, Train Acc: 0.14%, Val Loss: 7.6007, Val Acc: 0.04%
# Validation Accuracy: 0.0444
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0005, 'lstm_hidden_dim': 512, 'lstm_layers': 1, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6036, Train Acc: 0.04%, Val Loss: 7.6036, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5955, Train Acc: 0.04%, Val Loss: 7.6001, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.5660, Train Acc: 0.10%, Val Loss: 7.5099, Val Acc: 0.09%
# Epoch 4: Train Loss: 7.3582, Train Acc: 0.12%, Val Loss: 7.3225, Val Acc: 0.04%
# Epoch 5: Train Loss: 7.2131, Train Acc: 0.22%, Val Loss: 7.3203, Val Acc: 0.18%
# Epoch 6: Train Loss: 7.0773, Train Acc: 0.22%, Val Loss: 7.3295, Val Acc: 0.18%
# Epoch 7: Train Loss: 6.9576, Train Acc: 0.29%, Val Loss: 7.3070, Val Acc: 0.27%
# Epoch 8: Train Loss: 6.7970, Train Acc: 0.36%, Val Loss: 7.3068, Val Acc: 0.27%
# Epoch 9: Train Loss: 6.5904, Train Acc: 0.61%, Val Loss: 7.3904, Val Acc: 0.53%
# Epoch 10: Train Loss: 6.3435, Train Acc: 1.13%, Val Loss: 7.4382, Val Acc: 0.58%
# Epoch 11: Train Loss: 6.0316, Train Acc: 1.34%, Val Loss: 7.6192, Val Acc: 0.40%
# Epoch 12: Train Loss: 5.3052, Train Acc: 6.77%, Val Loss: 7.7439, Val Acc: 0.44%
# Validation Accuracy: 0.4439
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0005, 'lstm_hidden_dim': 512, 'lstm_layers': 1, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6047, Train Acc: 0.05%, Val Loss: 7.6059, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5961, Train Acc: 0.10%, Val Loss: 7.6004, Val Acc: 0.13%
# Epoch 3: Train Loss: 7.5646, Train Acc: 0.08%, Val Loss: 7.4847, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.3326, Train Acc: 0.18%, Val Loss: 7.3241, Val Acc: 0.09%
# Epoch 5: Train Loss: 7.1366, Train Acc: 0.16%, Val Loss: 7.3263, Val Acc: 0.04%
# Epoch 6: Train Loss: 7.0029, Train Acc: 0.18%, Val Loss: 7.3072, Val Acc: 0.22%
# Epoch 7: Train Loss: 6.8658, Train Acc: 0.20%, Val Loss: 7.3520, Val Acc: 0.31%
# Epoch 8: Train Loss: 6.6860, Train Acc: 0.57%, Val Loss: 7.4223, Val Acc: 0.44%
# Epoch 9: Train Loss: 6.4723, Train Acc: 0.84%, Val Loss: 7.4374, Val Acc: 0.49%
# Epoch 10: Train Loss: 6.2208, Train Acc: 1.05%, Val Loss: 7.5562, Val Acc: 0.40%
# Epoch 11: Train Loss: 5.5880, Train Acc: 4.55%, Val Loss: 7.6977, Val Acc: 0.67%
# Validation Accuracy: 0.6658
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0005, 'lstm_hidden_dim': 512, 'lstm_layers': 1, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6053, Train Acc: 0.02%, Val Loss: 7.6010, Val Acc: 0.00%
# Epoch 2: Train Loss: 7.5979, Train Acc: 0.10%, Val Loss: 7.6014, Val Acc: 0.09%
# Epoch 3: Train Loss: 7.5957, Train Acc: 0.08%, Val Loss: 7.6018, Val Acc: 0.13%
# Epoch 4: Train Loss: 7.5937, Train Acc: 0.13%, Val Loss: 7.6004, Val Acc: 0.09%
# Epoch 5: Train Loss: 7.5624, Train Acc: 0.10%, Val Loss: 7.4476, Val Acc: 0.09%
# Epoch 6: Train Loss: 7.3648, Train Acc: 0.11%, Val Loss: 7.3045, Val Acc: 0.22%
# Epoch 7: Train Loss: 7.2450, Train Acc: 0.14%, Val Loss: 7.2950, Val Acc: 0.27%
# Epoch 8: Train Loss: 7.1929, Train Acc: 0.08%, Val Loss: 7.2848, Val Acc: 0.13%
# Epoch 9: Train Loss: 7.1407, Train Acc: 0.12%, Val Loss: 7.2673, Val Acc: 0.13%
# Epoch 10: Train Loss: 7.0997, Train Acc: 0.22%, Val Loss: 7.2472, Val Acc: 0.04%
# Epoch 11: Train Loss: 7.0479, Train Acc: 0.24%, Val Loss: 7.2418, Val Acc: 0.18%
# Epoch 12: Train Loss: 7.0024, Train Acc: 0.23%, Val Loss: 7.2434, Val Acc: 0.27%
# Epoch 13: Train Loss: 6.9623, Train Acc: 0.26%, Val Loss: 7.2449, Val Acc: 0.22%
# Epoch 14: Train Loss: 6.9122, Train Acc: 0.26%, Val Loss: 7.2475, Val Acc: 0.27%
# Epoch 15: Train Loss: 6.8601, Train Acc: 0.34%, Val Loss: 7.2553, Val Acc: 0.36%
# Validation Accuracy: 0.3551
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0005, 'lstm_hidden_dim': 512, 'lstm_layers': 2, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6048, Train Acc: 0.04%, Val Loss: 7.6049, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5950, Train Acc: 0.04%, Val Loss: 7.6086, Val Acc: 0.09%
# Epoch 3: Train Loss: 7.5663, Train Acc: 0.10%, Val Loss: 7.4983, Val Acc: 0.27%
# Epoch 4: Train Loss: 7.3477, Train Acc: 0.11%, Val Loss: 7.3390, Val Acc: 0.13%
# Epoch 5: Train Loss: 7.1760, Train Acc: 0.08%, Val Loss: 7.2833, Val Acc: 0.18%
# Epoch 6: Train Loss: 7.0654, Train Acc: 0.24%, Val Loss: 7.2710, Val Acc: 0.18%
# Epoch 7: Train Loss: 6.9599, Train Acc: 0.29%, Val Loss: 7.2562, Val Acc: 0.31%
# Epoch 8: Train Loss: 6.7966, Train Acc: 0.49%, Val Loss: 7.2975, Val Acc: 0.27%
# Epoch 9: Train Loss: 6.5740, Train Acc: 0.69%, Val Loss: 7.3403, Val Acc: 0.49%
# Epoch 10: Train Loss: 6.2910, Train Acc: 1.06%, Val Loss: 7.4806, Val Acc: 0.44%
# Epoch 11: Train Loss: 5.9364, Train Acc: 1.71%, Val Loss: 7.7090, Val Acc: 0.53%
# Epoch 12: Train Loss: 5.1061, Train Acc: 7.93%, Val Loss: 7.8913, Val Acc: 0.53%
# Validation Accuracy: 0.5326
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0005, 'lstm_hidden_dim': 512, 'lstm_layers': 2, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6045, Train Acc: 0.04%, Val Loss: 7.6018, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5972, Train Acc: 0.07%, Val Loss: 7.6005, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.5230, Train Acc: 0.07%, Val Loss: 7.4015, Val Acc: 0.09%
# Epoch 4: Train Loss: 7.2986, Train Acc: 0.12%, Val Loss: 7.2913, Val Acc: 0.22%
# Epoch 5: Train Loss: 7.1813, Train Acc: 0.13%, Val Loss: 7.2831, Val Acc: 0.18%
# Epoch 6: Train Loss: 7.0988, Train Acc: 0.18%, Val Loss: 7.2410, Val Acc: 0.27%
# Epoch 7: Train Loss: 7.0202, Train Acc: 0.16%, Val Loss: 7.2660, Val Acc: 0.22%
# Epoch 8: Train Loss: 6.9559, Train Acc: 0.25%, Val Loss: 7.2619, Val Acc: 0.22%
# Epoch 9: Train Loss: 6.8930, Train Acc: 0.30%, Val Loss: 7.2601, Val Acc: 0.27%
# Epoch 10: Train Loss: 6.8178, Train Acc: 0.17%, Val Loss: 7.3277, Val Acc: 0.22%
# Epoch 11: Train Loss: 6.5443, Train Acc: 0.78%, Val Loss: 7.3969, Val Acc: 0.27%
# Validation Accuracy: 0.2663
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0005, 'lstm_hidden_dim': 512, 'lstm_layers': 2, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6048, Train Acc: 0.04%, Val Loss: 7.6005, Val Acc: 0.00%
# Epoch 2: Train Loss: 7.5974, Train Acc: 0.06%, Val Loss: 7.6006, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.5955, Train Acc: 0.14%, Val Loss: 7.6005, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.5938, Train Acc: 0.11%, Val Loss: 7.6004, Val Acc: 0.04%
# Epoch 5: Train Loss: 7.5922, Train Acc: 0.14%, Val Loss: 7.6004, Val Acc: 0.04%
# Epoch 6: Train Loss: 7.5897, Train Acc: 0.14%, Val Loss: 7.6004, Val Acc: 0.04%
# Validation Accuracy: 0.0444
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0001, 'lstm_hidden_dim': 128, 'lstm_layers': 1, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6058, Train Acc: 0.05%, Val Loss: 7.6007, Val Acc: 0.00%
# Epoch 2: Train Loss: 7.5959, Train Acc: 0.11%, Val Loss: 7.5996, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.5788, Train Acc: 0.13%, Val Loss: 7.5827, Val Acc: 0.09%
# Epoch 4: Train Loss: 7.4485, Train Acc: 0.20%, Val Loss: 7.4346, Val Acc: 0.04%
# Epoch 5: Train Loss: 7.2424, Train Acc: 0.31%, Val Loss: 7.3635, Val Acc: 0.04%
# Epoch 6: Train Loss: 7.1167, Train Acc: 0.23%, Val Loss: 7.3336, Val Acc: 0.04%
# Epoch 7: Train Loss: 7.0323, Train Acc: 0.36%, Val Loss: 7.3411, Val Acc: 0.13%
# Epoch 8: Train Loss: 6.9644, Train Acc: 0.32%, Val Loss: 7.3552, Val Acc: 0.04%
# Epoch 9: Train Loss: 6.9076, Train Acc: 0.48%, Val Loss: 7.3528, Val Acc: 0.13%
# Epoch 10: Train Loss: 6.8538, Train Acc: 0.47%, Val Loss: 7.3583, Val Acc: 0.13%
# Epoch 11: Train Loss: 6.7557, Train Acc: 0.84%, Val Loss: 7.3676, Val Acc: 0.13%
# Validation Accuracy: 0.1332
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0001, 'lstm_hidden_dim': 128, 'lstm_layers': 1, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6057, Train Acc: 0.00%, Val Loss: 7.6017, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5966, Train Acc: 0.11%, Val Loss: 7.6007, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.5849, Train Acc: 0.16%, Val Loss: 7.5903, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.4652, Train Acc: 0.14%, Val Loss: 7.4556, Val Acc: 0.18%
# Epoch 5: Train Loss: 7.2644, Train Acc: 0.20%, Val Loss: 7.3711, Val Acc: 0.13%
# Epoch 6: Train Loss: 7.1298, Train Acc: 0.30%, Val Loss: 7.3394, Val Acc: 0.18%
# Epoch 7: Train Loss: 7.0435, Train Acc: 0.42%, Val Loss: 7.3235, Val Acc: 0.13%
# Epoch 8: Train Loss: 6.9770, Train Acc: 0.40%, Val Loss: 7.3160, Val Acc: 0.09%
# Epoch 9: Train Loss: 6.9200, Train Acc: 0.46%, Val Loss: 7.3151, Val Acc: 0.09%
# Epoch 10: Train Loss: 6.8712, Train Acc: 0.52%, Val Loss: 7.3245, Val Acc: 0.09%
# Epoch 11: Train Loss: 6.8263, Train Acc: 0.69%, Val Loss: 7.3320, Val Acc: 0.04%
# Epoch 12: Train Loss: 6.7846, Train Acc: 0.71%, Val Loss: 7.3450, Val Acc: 0.09%
# Validation Accuracy: 0.0888
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0001, 'lstm_hidden_dim': 128, 'lstm_layers': 1, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6034, Train Acc: 0.00%, Val Loss: 7.6005, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5990, Train Acc: 0.02%, Val Loss: 7.6003, Val Acc: 0.09%
# Epoch 3: Train Loss: 7.5963, Train Acc: 0.06%, Val Loss: 7.6002, Val Acc: 0.13%
# Epoch 4: Train Loss: 7.5907, Train Acc: 0.13%, Val Loss: 7.5998, Val Acc: 0.13%
# Epoch 5: Train Loss: 7.5766, Train Acc: 0.12%, Val Loss: 7.6026, Val Acc: 0.13%
# Epoch 6: Train Loss: 7.5550, Train Acc: 0.13%, Val Loss: 7.6136, Val Acc: 0.13%
# Validation Accuracy: 0.1332
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0001, 'lstm_hidden_dim': 128, 'lstm_layers': 2, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6055, Train Acc: 0.04%, Val Loss: 7.6020, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5971, Train Acc: 0.11%, Val Loss: 7.6026, Val Acc: 0.13%
# Epoch 3: Train Loss: 7.5888, Train Acc: 0.07%, Val Loss: 7.6029, Val Acc: 0.09%
# Epoch 4: Train Loss: 7.5663, Train Acc: 0.05%, Val Loss: 7.6181, Val Acc: 0.09%
# Epoch 5: Train Loss: 7.5342, Train Acc: 0.11%, Val Loss: 7.6278, Val Acc: 0.09%
# Epoch 6: Train Loss: 7.4613, Train Acc: 0.14%, Val Loss: 7.6510, Val Acc: 0.04%
# Validation Accuracy: 0.0444
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0001, 'lstm_hidden_dim': 128, 'lstm_layers': 2, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6059, Train Acc: 0.06%, Val Loss: 7.6023, Val Acc: 0.00%
# Epoch 2: Train Loss: 7.5979, Train Acc: 0.11%, Val Loss: 7.6022, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.5905, Train Acc: 0.12%, Val Loss: 7.6028, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.5618, Train Acc: 0.14%, Val Loss: 7.6052, Val Acc: 0.04%
# Epoch 5: Train Loss: 7.4796, Train Acc: 0.20%, Val Loss: 7.5037, Val Acc: 0.18%
# Epoch 6: Train Loss: 7.2764, Train Acc: 0.16%, Val Loss: 7.3586, Val Acc: 0.18%
# Epoch 7: Train Loss: 7.1164, Train Acc: 0.25%, Val Loss: 7.3197, Val Acc: 0.18%
# Epoch 8: Train Loss: 7.0263, Train Acc: 0.22%, Val Loss: 7.2975, Val Acc: 0.22%
# Epoch 9: Train Loss: 6.9553, Train Acc: 0.34%, Val Loss: 7.2875, Val Acc: 0.22%
# Epoch 10: Train Loss: 6.8936, Train Acc: 0.51%, Val Loss: 7.3012, Val Acc: 0.22%
# Epoch 11: Train Loss: 6.8394, Train Acc: 0.59%, Val Loss: 7.2950, Val Acc: 0.18%
# Epoch 12: Train Loss: 6.7892, Train Acc: 0.54%, Val Loss: 7.2968, Val Acc: 0.36%
# Epoch 13: Train Loss: 6.7446, Train Acc: 0.71%, Val Loss: 7.3026, Val Acc: 0.44%
# Validation Accuracy: 0.4439
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0001, 'lstm_hidden_dim': 128, 'lstm_layers': 2, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6037, Train Acc: 0.04%, Val Loss: 7.6006, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5993, Train Acc: 0.08%, Val Loss: 7.6004, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.5964, Train Acc: 0.10%, Val Loss: 7.6002, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.5912, Train Acc: 0.07%, Val Loss: 7.6008, Val Acc: 0.13%
# Epoch 5: Train Loss: 7.5797, Train Acc: 0.13%, Val Loss: 7.6041, Val Acc: 0.13%
# Epoch 6: Train Loss: 7.5580, Train Acc: 0.13%, Val Loss: 7.6157, Val Acc: 0.13%
# Validation Accuracy: 0.1332
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0001, 'lstm_hidden_dim': 256, 'lstm_layers': 1, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6057, Train Acc: 0.05%, Val Loss: 7.6003, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5955, Train Acc: 0.11%, Val Loss: 7.6004, Val Acc: 0.09%
# Epoch 3: Train Loss: 7.5823, Train Acc: 0.11%, Val Loss: 7.5979, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.4708, Train Acc: 0.14%, Val Loss: 7.4335, Val Acc: 0.13%
# Epoch 5: Train Loss: 7.2309, Train Acc: 0.14%, Val Loss: 7.3512, Val Acc: 0.04%
# Epoch 6: Train Loss: 7.0785, Train Acc: 0.31%, Val Loss: 7.3303, Val Acc: 0.22%
# Epoch 7: Train Loss: 6.9711, Train Acc: 0.47%, Val Loss: 7.3382, Val Acc: 0.09%
# Epoch 8: Train Loss: 6.8810, Train Acc: 0.45%, Val Loss: 7.3708, Val Acc: 0.18%
# Epoch 9: Train Loss: 6.7961, Train Acc: 0.63%, Val Loss: 7.3844, Val Acc: 0.18%
# Epoch 10: Train Loss: 6.7181, Train Acc: 0.71%, Val Loss: 7.4245, Val Acc: 0.22%
# Epoch 11: Train Loss: 6.5526, Train Acc: 1.35%, Val Loss: 7.4331, Val Acc: 0.22%
# Validation Accuracy: 0.2219
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0001, 'lstm_hidden_dim': 256, 'lstm_layers': 1, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6061, Train Acc: 0.06%, Val Loss: 7.6013, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5955, Train Acc: 0.13%, Val Loss: 7.6011, Val Acc: 0.13%
# Epoch 3: Train Loss: 7.5785, Train Acc: 0.18%, Val Loss: 7.5953, Val Acc: 0.09%
# Epoch 4: Train Loss: 7.4358, Train Acc: 0.10%, Val Loss: 7.4186, Val Acc: 0.09%
# Epoch 5: Train Loss: 7.1808, Train Acc: 0.17%, Val Loss: 7.3546, Val Acc: 0.13%
# Epoch 6: Train Loss: 7.0247, Train Acc: 0.31%, Val Loss: 7.3633, Val Acc: 0.22%
# Epoch 7: Train Loss: 6.9205, Train Acc: 0.37%, Val Loss: 7.3803, Val Acc: 0.18%
# Epoch 8: Train Loss: 6.8280, Train Acc: 0.58%, Val Loss: 7.4098, Val Acc: 0.22%
# Epoch 9: Train Loss: 6.7466, Train Acc: 0.69%, Val Loss: 7.4374, Val Acc: 0.27%
# Epoch 10: Train Loss: 6.5761, Train Acc: 1.15%, Val Loss: 7.4452, Val Acc: 0.31%
# Validation Accuracy: 0.3107
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0001, 'lstm_hidden_dim': 256, 'lstm_layers': 1, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6036, Train Acc: 0.05%, Val Loss: 7.6004, Val Acc: 0.00%
# Epoch 2: Train Loss: 7.5985, Train Acc: 0.08%, Val Loss: 7.6002, Val Acc: 0.00%
# Epoch 3: Train Loss: 7.5956, Train Acc: 0.10%, Val Loss: 7.5998, Val Acc: 0.00%
# Epoch 4: Train Loss: 7.5842, Train Acc: 0.07%, Val Loss: 7.6021, Val Acc: 0.13%
# Epoch 5: Train Loss: 7.5693, Train Acc: 0.10%, Val Loss: 7.6033, Val Acc: 0.09%
# Epoch 6: Train Loss: 7.5373, Train Acc: 0.17%, Val Loss: 7.6242, Val Acc: 0.09%
# Validation Accuracy: 0.0888
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0001, 'lstm_hidden_dim': 256, 'lstm_layers': 2, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6052, Train Acc: 0.06%, Val Loss: 7.6017, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5975, Train Acc: 0.08%, Val Loss: 7.6009, Val Acc: 0.09%
# Epoch 3: Train Loss: 7.5824, Train Acc: 0.12%, Val Loss: 7.5981, Val Acc: 0.13%
# Epoch 4: Train Loss: 7.4807, Train Acc: 0.12%, Val Loss: 7.3831, Val Acc: 0.00%
# Epoch 5: Train Loss: 7.2405, Train Acc: 0.14%, Val Loss: 7.2927, Val Acc: 0.13%
# Epoch 6: Train Loss: 7.1069, Train Acc: 0.23%, Val Loss: 7.2894, Val Acc: 0.22%
# Epoch 7: Train Loss: 7.0192, Train Acc: 0.18%, Val Loss: 7.2865, Val Acc: 0.22%
# Epoch 8: Train Loss: 6.9374, Train Acc: 0.36%, Val Loss: 7.3007, Val Acc: 0.22%
# Epoch 9: Train Loss: 6.8698, Train Acc: 0.32%, Val Loss: 7.3128, Val Acc: 0.09%
# Epoch 10: Train Loss: 6.7995, Train Acc: 0.51%, Val Loss: 7.3248, Val Acc: 0.18%
# Validation Accuracy: 0.1775
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0001, 'lstm_hidden_dim': 256, 'lstm_layers': 2, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6043, Train Acc: 0.02%, Val Loss: 7.6059, Val Acc: 0.00%
# Epoch 2: Train Loss: 7.5975, Train Acc: 0.12%, Val Loss: 7.6021, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.5878, Train Acc: 0.10%, Val Loss: 7.6018, Val Acc: 0.09%
# Epoch 4: Train Loss: 7.5694, Train Acc: 0.11%, Val Loss: 7.6115, Val Acc: 0.09%
# Epoch 5: Train Loss: 7.5401, Train Acc: 0.17%, Val Loss: 7.5947, Val Acc: 0.09%
# Epoch 6: Train Loss: 7.4456, Train Acc: 0.11%, Val Loss: 7.4774, Val Acc: 0.09%
# Epoch 7: Train Loss: 7.2490, Train Acc: 0.18%, Val Loss: 7.3764, Val Acc: 0.22%
# Epoch 8: Train Loss: 7.0813, Train Acc: 0.26%, Val Loss: 7.3635, Val Acc: 0.13%
# Epoch 9: Train Loss: 6.9720, Train Acc: 0.29%, Val Loss: 7.3842, Val Acc: 0.13%
# Epoch 10: Train Loss: 6.8847, Train Acc: 0.37%, Val Loss: 7.3663, Val Acc: 0.22%
# Epoch 11: Train Loss: 6.7958, Train Acc: 0.48%, Val Loss: 7.3861, Val Acc: 0.18%
# Epoch 12: Train Loss: 6.7164, Train Acc: 0.63%, Val Loss: 7.3728, Val Acc: 0.31%
# Epoch 13: Train Loss: 6.5206, Train Acc: 1.14%, Val Loss: 7.4039, Val Acc: 0.27%
# Validation Accuracy: 0.2663
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0001, 'lstm_hidden_dim': 256, 'lstm_layers': 2, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6039, Train Acc: 0.06%, Val Loss: 7.6009, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5986, Train Acc: 0.08%, Val Loss: 7.6006, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.5946, Train Acc: 0.12%, Val Loss: 7.6006, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.5861, Train Acc: 0.13%, Val Loss: 7.6016, Val Acc: 0.04%
# Epoch 5: Train Loss: 7.5742, Train Acc: 0.12%, Val Loss: 7.6098, Val Acc: 0.04%
# Epoch 6: Train Loss: 7.5466, Train Acc: 0.14%, Val Loss: 7.6358, Val Acc: 0.04%
# Validation Accuracy: 0.0444
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0001, 'lstm_hidden_dim': 512, 'lstm_layers': 1, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6066, Train Acc: 0.10%, Val Loss: 7.6013, Val Acc: 0.00%
# Epoch 2: Train Loss: 7.5953, Train Acc: 0.13%, Val Loss: 7.6002, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.4919, Train Acc: 0.08%, Val Loss: 7.3881, Val Acc: 0.13%
# Epoch 4: Train Loss: 7.2404, Train Acc: 0.20%, Val Loss: 7.3219, Val Acc: 0.27%
# Epoch 5: Train Loss: 7.1090, Train Acc: 0.28%, Val Loss: 7.2837, Val Acc: 0.18%
# Epoch 6: Train Loss: 7.0270, Train Acc: 0.19%, Val Loss: 7.3087, Val Acc: 0.13%
# Epoch 7: Train Loss: 6.9390, Train Acc: 0.29%, Val Loss: 7.3397, Val Acc: 0.18%
# Epoch 8: Train Loss: 6.8462, Train Acc: 0.42%, Val Loss: 7.3661, Val Acc: 0.09%
# Epoch 9: Train Loss: 6.7605, Train Acc: 0.49%, Val Loss: 7.3786, Val Acc: 0.27%
# Epoch 10: Train Loss: 6.5476, Train Acc: 0.96%, Val Loss: 7.4145, Val Acc: 0.27%
# Validation Accuracy: 0.2663
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0001, 'lstm_hidden_dim': 512, 'lstm_layers': 1, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6057, Train Acc: 0.01%, Val Loss: 7.6044, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5965, Train Acc: 0.08%, Val Loss: 7.6032, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.5706, Train Acc: 0.08%, Val Loss: 7.5185, Val Acc: 0.00%
# Epoch 4: Train Loss: 7.3519, Train Acc: 0.16%, Val Loss: 7.3283, Val Acc: 0.18%
# Epoch 5: Train Loss: 7.1441, Train Acc: 0.24%, Val Loss: 7.3147, Val Acc: 0.22%
# Epoch 6: Train Loss: 7.0261, Train Acc: 0.26%, Val Loss: 7.3077, Val Acc: 0.22%
# Epoch 7: Train Loss: 6.9313, Train Acc: 0.31%, Val Loss: 7.3330, Val Acc: 0.22%
# Epoch 8: Train Loss: 6.8466, Train Acc: 0.47%, Val Loss: 7.3725, Val Acc: 0.27%
# Epoch 9: Train Loss: 6.7619, Train Acc: 0.48%, Val Loss: 7.4134, Val Acc: 0.09%
# Epoch 10: Train Loss: 6.6765, Train Acc: 0.61%, Val Loss: 7.4284, Val Acc: 0.27%
# Validation Accuracy: 0.2663
# Training with parameters: {'cnn_hidden_dim': 64, 'learning_rate': 0.0001, 'lstm_hidden_dim': 512, 'lstm_layers': 1, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6040, Train Acc: 0.05%, Val Loss: 7.6011, Val Acc: 0.18%
# Epoch 2: Train Loss: 7.5982, Train Acc: 0.13%, Val Loss: 7.6007, Val Acc: 0.13%
# Epoch 3: Train Loss: 7.5942, Train Acc: 0.11%, Val Loss: 7.6003, Val Acc: 0.13%
# Epoch 4: Train Loss: 7.5823, Train Acc: 0.17%, Val Loss: 7.6005, Val Acc: 0.09%
# Epoch 5: Train Loss: 7.5673, Train Acc: 0.10%, Val Loss: 7.6067, Val Acc: 0.13%
# Epoch 6: Train Loss: 7.5415, Train Acc: 0.06%, Val Loss: 7.5870, Val Acc: 0.09%
# Epoch 7: Train Loss: 7.4613, Train Acc: 0.11%, Val Loss: 7.4929, Val Acc: 0.27%
# Epoch 8: Train Loss: 7.2699, Train Acc: 0.17%, Val Loss: 7.3441, Val Acc: 0.22%
# Epoch 9: Train Loss: 7.1011, Train Acc: 0.07%, Val Loss: 7.3278, Val Acc: 0.22%
# Epoch 10: Train Loss: 7.0099, Train Acc: 0.19%, Val Loss: 7.3271, Val Acc: 0.22%
# Epoch 11: Train Loss: 6.9392, Train Acc: 0.30%, Val Loss: 7.3349, Val Acc: 0.00%
# Epoch 12: Train Loss: 6.8804, Train Acc: 0.36%, Val Loss: 7.3574, Val Acc: 0.22%
# Epoch 13: Train Loss: 6.8247, Train Acc: 0.45%, Val Loss: 7.3762, Val Acc: 0.18%
# ...
# Epoch 9: Train Loss: 6.8705, Train Acc: 0.53%, Val Loss: 7.3129, Val Acc: 0.18%
# Epoch 10: Train Loss: 6.7648, Train Acc: 0.94%, Val Loss: 7.3253, Val Acc: 0.04%
# Validation Accuracy: 0.0444
# Training with parameters: {'cnn_hidden_dim': 256, 'learning_rate': 0.0001, 'lstm_hidden_dim': 128, 'lstm_layers': 1, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6041, Train Acc: 0.05%, Val Loss: 7.6021, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5983, Train Acc: 0.06%, Val Loss: 7.6011, Val Acc: 0.13%
# Epoch 3: Train Loss: 7.5871, Train Acc: 0.13%, Val Loss: 7.5699, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.4318, Train Acc: 0.17%, Val Loss: 7.3873, Val Acc: 0.31%
# Epoch 5: Train Loss: 7.2558, Train Acc: 0.14%, Val Loss: 7.3344, Val Acc: 0.31%
# Epoch 6: Train Loss: 7.1578, Train Acc: 0.26%, Val Loss: 7.2996, Val Acc: 0.22%
# Epoch 7: Train Loss: 7.0908, Train Acc: 0.24%, Val Loss: 7.3034, Val Acc: 0.13%
# Epoch 8: Train Loss: 7.0318, Train Acc: 0.35%, Val Loss: 7.2905, Val Acc: 0.13%
# Epoch 9: Train Loss: 6.9795, Train Acc: 0.38%, Val Loss: 7.2856, Val Acc: 0.27%
# Epoch 10: Train Loss: 6.9344, Train Acc: 0.52%, Val Loss: 7.3050, Val Acc: 0.09%
# Epoch 11: Train Loss: 6.8899, Train Acc: 0.53%, Val Loss: 7.3007, Val Acc: 0.09%
# Epoch 12: Train Loss: 6.8499, Train Acc: 0.63%, Val Loss: 7.3150, Val Acc: 0.18%
# Epoch 13: Train Loss: 6.8126, Train Acc: 0.57%, Val Loss: 7.3193, Val Acc: 0.22%
# Epoch 14: Train Loss: 6.7208, Train Acc: 1.06%, Val Loss: 7.3188, Val Acc: 0.31%
# Validation Accuracy: 0.3107
# Training with parameters: {'cnn_hidden_dim': 256, 'learning_rate': 0.0001, 'lstm_hidden_dim': 128, 'lstm_layers': 2, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6046, Train Acc: 0.07%, Val Loss: 7.6079, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5986, Train Acc: 0.10%, Val Loss: 7.6000, Val Acc: 0.09%
# Epoch 3: Train Loss: 7.5576, Train Acc: 0.14%, Val Loss: 7.4785, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.3285, Train Acc: 0.11%, Val Loss: 7.3161, Val Acc: 0.22%
# Epoch 5: Train Loss: 7.1718, Train Acc: 0.24%, Val Loss: 7.2770, Val Acc: 0.13%
# Epoch 6: Train Loss: 7.0987, Train Acc: 0.20%, Val Loss: 7.2535, Val Acc: 0.13%
# Epoch 7: Train Loss: 7.0376, Train Acc: 0.29%, Val Loss: 7.2376, Val Acc: 0.22%
# Epoch 8: Train Loss: 6.9819, Train Acc: 0.36%, Val Loss: 7.2334, Val Acc: 0.22%
# Epoch 9: Train Loss: 6.9344, Train Acc: 0.30%, Val Loss: 7.2422, Val Acc: 0.27%
# Epoch 10: Train Loss: 6.8865, Train Acc: 0.53%, Val Loss: 7.2403, Val Acc: 0.27%
# Epoch 11: Train Loss: 6.8434, Train Acc: 0.51%, Val Loss: 7.2321, Val Acc: 0.31%
# Epoch 12: Train Loss: 6.7983, Train Acc: 0.49%, Val Loss: 7.2447, Val Acc: 0.22%
# Validation Accuracy: 0.2219
# Training with parameters: {'cnn_hidden_dim': 256, 'learning_rate': 0.0001, 'lstm_hidden_dim': 128, 'lstm_layers': 2, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6046, Train Acc: 0.01%, Val Loss: 7.6026, Val Acc: 0.00%
# Epoch 2: Train Loss: 7.5985, Train Acc: 0.05%, Val Loss: 7.6013, Val Acc: 0.13%
# Epoch 3: Train Loss: 7.5839, Train Acc: 0.08%, Val Loss: 7.5755, Val Acc: 0.18%
# Epoch 4: Train Loss: 7.4353, Train Acc: 0.16%, Val Loss: 7.3808, Val Acc: 0.04%
# Epoch 5: Train Loss: 7.2256, Train Acc: 0.22%, Val Loss: 7.3112, Val Acc: 0.13%
# Epoch 6: Train Loss: 7.1274, Train Acc: 0.20%, Val Loss: 7.2808, Val Acc: 0.13%
# Epoch 7: Train Loss: 7.0554, Train Acc: 0.31%, Val Loss: 7.2769, Val Acc: 0.18%
# Epoch 8: Train Loss: 6.9941, Train Acc: 0.28%, Val Loss: 7.2623, Val Acc: 0.13%
# Epoch 9: Train Loss: 6.9342, Train Acc: 0.43%, Val Loss: 7.2742, Val Acc: 0.18%
# Epoch 10: Train Loss: 6.8771, Train Acc: 0.51%, Val Loss: 7.2638, Val Acc: 0.13%
# Epoch 11: Train Loss: 6.8201, Train Acc: 0.58%, Val Loss: 7.2647, Val Acc: 0.22%
# Epoch 12: Train Loss: 6.7601, Train Acc: 0.67%, Val Loss: 7.2472, Val Acc: 0.31%
# Epoch 13: Train Loss: 6.7033, Train Acc: 0.75%, Val Loss: 7.2613, Val Acc: 0.22%
# Epoch 14: Train Loss: 6.6525, Train Acc: 0.93%, Val Loss: 7.2659, Val Acc: 0.22%
# Epoch 15: Train Loss: 6.6040, Train Acc: 1.18%, Val Loss: 7.2685, Val Acc: 0.22%
# Epoch 16: Train Loss: 6.5550, Train Acc: 1.18%, Val Loss: 7.2764, Val Acc: 0.40%
# Epoch 17: Train Loss: 6.4360, Train Acc: 1.77%, Val Loss: 7.2724, Val Acc: 0.44%
# Validation Accuracy: 0.4439
# Training with parameters: {'cnn_hidden_dim': 256, 'learning_rate': 0.0001, 'lstm_hidden_dim': 128, 'lstm_layers': 2, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6042, Train Acc: 0.00%, Val Loss: 7.6017, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5995, Train Acc: 0.08%, Val Loss: 7.6014, Val Acc: 0.13%
# Epoch 3: Train Loss: 7.5963, Train Acc: 0.05%, Val Loss: 7.6012, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.5883, Train Acc: 0.07%, Val Loss: 7.6014, Val Acc: 0.04%
# Epoch 5: Train Loss: 7.5733, Train Acc: 0.11%, Val Loss: 7.6029, Val Acc: 0.04%
# Epoch 6: Train Loss: 7.5482, Train Acc: 0.14%, Val Loss: 7.6245, Val Acc: 0.04%
# Validation Accuracy: 0.0444
# Training with parameters: {'cnn_hidden_dim': 256, 'learning_rate': 0.0001, 'lstm_hidden_dim': 256, 'lstm_layers': 1, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6057, Train Acc: 0.02%, Val Loss: 7.6019, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5897, Train Acc: 0.08%, Val Loss: 7.5588, Val Acc: 0.00%
# Epoch 3: Train Loss: 7.3842, Train Acc: 0.11%, Val Loss: 7.3369, Val Acc: 0.27%
# Epoch 4: Train Loss: 7.1623, Train Acc: 0.18%, Val Loss: 7.2913, Val Acc: 0.36%
# Epoch 5: Train Loss: 7.0408, Train Acc: 0.28%, Val Loss: 7.2968, Val Acc: 0.22%
# Epoch 6: Train Loss: 6.9455, Train Acc: 0.35%, Val Loss: 7.3164, Val Acc: 0.22%
# Epoch 7: Train Loss: 6.8549, Train Acc: 0.57%, Val Loss: 7.3130, Val Acc: 0.36%
# Epoch 8: Train Loss: 6.7674, Train Acc: 0.64%, Val Loss: 7.3542, Val Acc: 0.36%
# Epoch 9: Train Loss: 6.5851, Train Acc: 1.24%, Val Loss: 7.3655, Val Acc: 0.40%
# Validation Accuracy: 0.3995
# Training with parameters: {'cnn_hidden_dim': 256, 'learning_rate': 0.0001, 'lstm_hidden_dim': 256, 'lstm_layers': 1, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6056, Train Acc: 0.06%, Val Loss: 7.6030, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5957, Train Acc: 0.07%, Val Loss: 7.5922, Val Acc: 0.00%
# Epoch 3: Train Loss: 7.4410, Train Acc: 0.22%, Val Loss: 7.3616, Val Acc: 0.09%
# Epoch 4: Train Loss: 7.1999, Train Acc: 0.17%, Val Loss: 7.3130, Val Acc: 0.09%
# Epoch 5: Train Loss: 7.0706, Train Acc: 0.23%, Val Loss: 7.3047, Val Acc: 0.13%
# Epoch 6: Train Loss: 6.9718, Train Acc: 0.42%, Val Loss: 7.3063, Val Acc: 0.09%
# Epoch 7: Train Loss: 6.8795, Train Acc: 0.54%, Val Loss: 7.3354, Val Acc: 0.31%
# Epoch 8: Train Loss: 6.7950, Train Acc: 0.55%, Val Loss: 7.3506, Val Acc: 0.18%
# Epoch 9: Train Loss: 6.7114, Train Acc: 0.76%, Val Loss: 7.3932, Val Acc: 0.44%
# Validation Accuracy: 0.4439
# Training with parameters: {'cnn_hidden_dim': 256, 'learning_rate': 0.0001, 'lstm_hidden_dim': 256, 'lstm_layers': 1, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6043, Train Acc: 0.07%, Val Loss: 7.6006, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5983, Train Acc: 0.14%, Val Loss: 7.6001, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.5903, Train Acc: 0.13%, Val Loss: 7.5990, Val Acc: 0.09%
# Epoch 4: Train Loss: 7.5454, Train Acc: 0.13%, Val Loss: 7.4857, Val Acc: 0.13%
# Epoch 5: Train Loss: 7.3161, Train Acc: 0.14%, Val Loss: 7.3384, Val Acc: 0.18%
# Epoch 6: Train Loss: 7.1312, Train Acc: 0.22%, Val Loss: 7.3096, Val Acc: 0.18%
# Epoch 7: Train Loss: 7.0260, Train Acc: 0.23%, Val Loss: 7.3301, Val Acc: 0.18%
# Epoch 8: Train Loss: 6.9403, Train Acc: 0.42%, Val Loss: 7.3173, Val Acc: 0.27%
# Epoch 9: Train Loss: 6.8662, Train Acc: 0.54%, Val Loss: 7.3305, Val Acc: 0.27%
# Epoch 10: Train Loss: 6.8010, Train Acc: 0.61%, Val Loss: 7.3417, Val Acc: 0.22%
# Epoch 11: Train Loss: 6.6416, Train Acc: 1.13%, Val Loss: 7.3573, Val Acc: 0.22%
# Validation Accuracy: 0.2219
# Training with parameters: {'cnn_hidden_dim': 256, 'learning_rate': 0.0001, 'lstm_hidden_dim': 256, 'lstm_layers': 2, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6045, Train Acc: 0.05%, Val Loss: 7.6069, Val Acc: 0.00%
# Epoch 2: Train Loss: 7.5885, Train Acc: 0.14%, Val Loss: 7.5356, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.3702, Train Acc: 0.10%, Val Loss: 7.3106, Val Acc: 0.18%
# Epoch 4: Train Loss: 7.1778, Train Acc: 0.16%, Val Loss: 7.2544, Val Acc: 0.27%
# Epoch 5: Train Loss: 7.0723, Train Acc: 0.16%, Val Loss: 7.2126, Val Acc: 0.31%
# Epoch 6: Train Loss: 6.9808, Train Acc: 0.41%, Val Loss: 7.2052, Val Acc: 0.36%
# Epoch 7: Train Loss: 6.8915, Train Acc: 0.38%, Val Loss: 7.2222, Val Acc: 0.13%
# Epoch 8: Train Loss: 6.8011, Train Acc: 0.57%, Val Loss: 7.2187, Val Acc: 0.18%
# Epoch 9: Train Loss: 6.7186, Train Acc: 0.61%, Val Loss: 7.2396, Val Acc: 0.27%
# Epoch 10: Train Loss: 6.6330, Train Acc: 0.73%, Val Loss: 7.2567, Val Acc: 0.31%
# Validation Accuracy: 0.3107
# Training with parameters: {'cnn_hidden_dim': 256, 'learning_rate': 0.0001, 'lstm_hidden_dim': 256, 'lstm_layers': 2, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6043, Train Acc: 0.05%, Val Loss: 7.6041, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5975, Train Acc: 0.05%, Val Loss: 7.6008, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.5568, Train Acc: 0.07%, Val Loss: 7.5145, Val Acc: 0.18%
# Epoch 4: Train Loss: 7.3106, Train Acc: 0.17%, Val Loss: 7.3180, Val Acc: 0.09%
# Epoch 5: Train Loss: 7.1178, Train Acc: 0.19%, Val Loss: 7.2812, Val Acc: 0.09%
# Epoch 6: Train Loss: 7.0104, Train Acc: 0.31%, Val Loss: 7.2848, Val Acc: 0.18%
# Epoch 7: Train Loss: 6.8990, Train Acc: 0.42%, Val Loss: 7.2820, Val Acc: 0.22%
# Epoch 8: Train Loss: 6.8045, Train Acc: 0.57%, Val Loss: 7.2793, Val Acc: 0.36%
# Epoch 9: Train Loss: 6.7080, Train Acc: 0.71%, Val Loss: 7.2957, Val Acc: 0.36%
# Epoch 10: Train Loss: 6.6147, Train Acc: 0.79%, Val Loss: 7.3158, Val Acc: 0.31%
# Validation Accuracy: 0.3107
# Training with parameters: {'cnn_hidden_dim': 256, 'learning_rate': 0.0001, 'lstm_hidden_dim': 256, 'lstm_layers': 2, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6041, Train Acc: 0.04%, Val Loss: 7.6007, Val Acc: 0.04%
# Epoch 2: Train Loss: 7.5989, Train Acc: 0.14%, Val Loss: 7.6004, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.5950, Train Acc: 0.11%, Val Loss: 7.6002, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.5870, Train Acc: 0.12%, Val Loss: 7.6012, Val Acc: 0.04%
# Epoch 5: Train Loss: 7.5753, Train Acc: 0.11%, Val Loss: 7.6050, Val Acc: 0.04%
# Epoch 6: Train Loss: 7.5470, Train Acc: 0.14%, Val Loss: 7.6293, Val Acc: 0.13%
# Validation Accuracy: 0.1332
# Training with parameters: {'cnn_hidden_dim': 256, 'learning_rate': 0.0001, 'lstm_hidden_dim': 512, 'lstm_layers': 1, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6047, Train Acc: 0.06%, Val Loss: 7.6016, Val Acc: 0.00%
# Epoch 2: Train Loss: 7.5889, Train Acc: 0.11%, Val Loss: 7.5543, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.3808, Train Acc: 0.07%, Val Loss: 7.3241, Val Acc: 0.04%
# Epoch 4: Train Loss: 7.1432, Train Acc: 0.16%, Val Loss: 7.3121, Val Acc: 0.18%
# Epoch 5: Train Loss: 7.0046, Train Acc: 0.31%, Val Loss: 7.3245, Val Acc: 0.18%
# Epoch 6: Train Loss: 6.8823, Train Acc: 0.37%, Val Loss: 7.3410, Val Acc: 0.22%
# Epoch 7: Train Loss: 6.7624, Train Acc: 0.46%, Val Loss: 7.3764, Val Acc: 0.27%
# Epoch 8: Train Loss: 6.6333, Train Acc: 0.78%, Val Loss: 7.4127, Val Acc: 0.40%
# Epoch 9: Train Loss: 6.3391, Train Acc: 2.07%, Val Loss: 7.4525, Val Acc: 0.31%
# Validation Accuracy: 0.3107
# Training with parameters: {'cnn_hidden_dim': 256, 'learning_rate': 0.0001, 'lstm_hidden_dim': 512, 'lstm_layers': 1, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6052, Train Acc: 0.05%, Val Loss: 7.6034, Val Acc: 0.00%
# Epoch 2: Train Loss: 7.5882, Train Acc: 0.11%, Val Loss: 7.5601, Val Acc: 0.13%
# Epoch 3: Train Loss: 7.3903, Train Acc: 0.16%, Val Loss: 7.3216, Val Acc: 0.13%
# Epoch 4: Train Loss: 7.1613, Train Acc: 0.20%, Val Loss: 7.2788, Val Acc: 0.13%
# Epoch 5: Train Loss: 7.0246, Train Acc: 0.26%, Val Loss: 7.2922, Val Acc: 0.18%
# Epoch 6: Train Loss: 6.8991, Train Acc: 0.32%, Val Loss: 7.3042, Val Acc: 0.13%
# Epoch 7: Train Loss: 6.7789, Train Acc: 0.52%, Val Loss: 7.3403, Val Acc: 0.40%
# Epoch 8: Train Loss: 6.6544, Train Acc: 0.60%, Val Loss: 7.3859, Val Acc: 0.27%
# Epoch 9: Train Loss: 6.3755, Train Acc: 1.61%, Val Loss: 7.4294, Val Acc: 0.31%
# Validation Accuracy: 0.3107
# Training with parameters: {'cnn_hidden_dim': 256, 'learning_rate': 0.0001, 'lstm_hidden_dim': 512, 'lstm_layers': 1, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6044, Train Acc: 0.04%, Val Loss: 7.6006, Val Acc: 0.13%
# Epoch 2: Train Loss: 7.5988, Train Acc: 0.12%, Val Loss: 7.6000, Val Acc: 0.13%
# Epoch 3: Train Loss: 7.5925, Train Acc: 0.11%, Val Loss: 7.5998, Val Acc: 0.09%
# Epoch 4: Train Loss: 7.4796, Train Acc: 0.13%, Val Loss: 7.3549, Val Acc: 0.18%
# Epoch 5: Train Loss: 7.2291, Train Acc: 0.19%, Val Loss: 7.3005, Val Acc: 0.18%
# Epoch 6: Train Loss: 7.0896, Train Acc: 0.26%, Val Loss: 7.2902, Val Acc: 0.13%
# Epoch 7: Train Loss: 6.9927, Train Acc: 0.26%, Val Loss: 7.3079, Val Acc: 0.09%
# Epoch 8: Train Loss: 6.9025, Train Acc: 0.35%, Val Loss: 7.3248, Val Acc: 0.27%
# Epoch 9: Train Loss: 6.8057, Train Acc: 0.51%, Val Loss: 7.3795, Val Acc: 0.09%
# Epoch 10: Train Loss: 6.7094, Train Acc: 0.66%, Val Loss: 7.3991, Val Acc: 0.13%
# Epoch 11: Train Loss: 6.4580, Train Acc: 1.53%, Val Loss: 7.4095, Val Acc: 0.31%
# Validation Accuracy: 0.3107
# Training with parameters: {'cnn_hidden_dim': 256, 'learning_rate': 0.0001, 'lstm_hidden_dim': 512, 'lstm_layers': 2, 'weight_decay': 1e-05}
# Epoch 1: Train Loss: 7.6040, Train Acc: 0.02%, Val Loss: 7.6105, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5963, Train Acc: 0.12%, Val Loss: 7.5991, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.4695, Train Acc: 0.06%, Val Loss: 7.3444, Val Acc: 0.09%
# Epoch 4: Train Loss: 7.2304, Train Acc: 0.18%, Val Loss: 7.2620, Val Acc: 0.04%
# Epoch 5: Train Loss: 7.0874, Train Acc: 0.23%, Val Loss: 7.2419, Val Acc: 0.22%
# Epoch 6: Train Loss: 6.9587, Train Acc: 0.32%, Val Loss: 7.3227, Val Acc: 0.13%
# Epoch 7: Train Loss: 6.8422, Train Acc: 0.40%, Val Loss: 7.2310, Val Acc: 0.22%
# Epoch 8: Train Loss: 6.7000, Train Acc: 0.64%, Val Loss: 7.2991, Val Acc: 0.31%
# Epoch 9: Train Loss: 6.5657, Train Acc: 0.70%, Val Loss: 7.3157, Val Acc: 0.13%
# Epoch 10: Train Loss: 6.4256, Train Acc: 0.82%, Val Loss: 7.3715, Val Acc: 0.36%
# Epoch 11: Train Loss: 6.2841, Train Acc: 0.96%, Val Loss: 7.4095, Val Acc: 0.67%
# Epoch 12: Train Loss: 5.9452, Train Acc: 2.92%, Val Loss: 7.4380, Val Acc: 0.67%
# Validation Accuracy: 0.6658
# Training with parameters: {'cnn_hidden_dim': 256, 'learning_rate': 0.0001, 'lstm_hidden_dim': 512, 'lstm_layers': 2, 'weight_decay': 0.0001}
# Epoch 1: Train Loss: 7.6029, Train Acc: 0.08%, Val Loss: 7.6353, Val Acc: 0.09%
# Epoch 2: Train Loss: 7.5982, Train Acc: 0.08%, Val Loss: 7.5983, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.4602, Train Acc: 0.11%, Val Loss: 7.3309, Val Acc: 0.18%
# Epoch 4: Train Loss: 7.2299, Train Acc: 0.11%, Val Loss: 7.2681, Val Acc: 0.18%
# Epoch 5: Train Loss: 7.1149, Train Acc: 0.25%, Val Loss: 7.2083, Val Acc: 0.13%
# Epoch 6: Train Loss: 7.0160, Train Acc: 0.23%, Val Loss: 7.2282, Val Acc: 0.09%
# Epoch 7: Train Loss: 6.9166, Train Acc: 0.35%, Val Loss: 7.2472, Val Acc: 0.13%
# Epoch 8: Train Loss: 6.8058, Train Acc: 0.48%, Val Loss: 7.2609, Val Acc: 0.18%
# Epoch 9: Train Loss: 6.7017, Train Acc: 0.53%, Val Loss: 7.2862, Val Acc: 0.31%
# Epoch 10: Train Loss: 6.4202, Train Acc: 1.19%, Val Loss: 7.3044, Val Acc: 0.22%
# Validation Accuracy: 0.2219
# Training with parameters: {'cnn_hidden_dim': 256, 'learning_rate': 0.0001, 'lstm_hidden_dim': 512, 'lstm_layers': 2, 'weight_decay': 0.001}
# Epoch 1: Train Loss: 7.6038, Train Acc: 0.05%, Val Loss: 7.6007, Val Acc: 0.13%
# Epoch 2: Train Loss: 7.5986, Train Acc: 0.12%, Val Loss: 7.6003, Val Acc: 0.04%
# Epoch 3: Train Loss: 7.5940, Train Acc: 0.14%, Val Loss: 7.6004, Val Acc: 0.13%
# Epoch 4: Train Loss: 7.5847, Train Acc: 0.07%, Val Loss: 7.6038, Val Acc: 0.04%
# Epoch 5: Train Loss: 7.5734, Train Acc: 0.11%, Val Loss: 7.6018, Val Acc: 0.04%
# Epoch 6: Train Loss: 7.5480, Train Acc: 0.14%, Val Loss: 7.6308, Val Acc: 0.04%
# Validation Accuracy: 0.0444
# Best Hyperparameters: {'cnn_hidden_dim': 256, 'learning_rate': 0.001, 'lstm_hidden_dim': 128, 'lstm_layers': 1, 'weight_decay': 1e-05}
# Best Validation Accuracy: 0.8877
